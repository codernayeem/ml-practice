# %% [markdown]
# ## Linear Regression With One Variable

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('datasets/canada_per_capita_income.csv')
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
df.shape
# Out:
# (47, 2)

# %%
df.describe()
# Out:
#               year  per capita income (US$)
# count    47.000000                47.000000
# mean   1993.000000             18920.137063
# std      13.711309             12034.679438
# min    1970.000000              3399.299037
# 25%    1981.500000              9526.914515
# 50%    1993.000000             16426.725480
# 75%    2004.500000             27458.601420
# max    2016.000000             42676.468370

# %%
plt.scatter(df['year'], df['per capita income (US$)'], marker='+')
plt.xlabel('Year')
plt.ylabel('Per capita income (US$)')
plt.title('Per capita income (US$) (1970 - 2016)')
# Out:
# Text(0.5, 1.0, 'Per capita income (US$) (1970 - 2016)')

# %%
X = df[['year']]
y = df['per capita income (US$)']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Score on train set
model.score(X_train, y_train)
# Out:
# 0.8866618879742149

# %%
# Score on test set
model.score(X_test, y_test)
# Out:
# 0.8968448121213726

# %%
model.predict([[1997], [2001]])
# Out:
# array([22285.95371066, 25730.62173761])

# %%
y_pred = model.predict(X)

# %%
# Weights
model.coef_
# Out:
# array([861.16700674])

# %%
# Bias
model.intercept_
# Out:
# -1697464.5587414696

# %%
plt.scatter(X, y, marker='+')
plt.plot(X, y_pred, color='r')
plt.xlabel('Year')
plt.ylabel('Per capita income (US$)')
plt.title('Per capita income (US$) (1970 - 2016)')
plt.show()

# %%
# A Quick RegPlot using seaborn
sns.regplot(X, y)
# Out:
# <AxesSubplot:xlabel='year', ylabel='per capita income (US$)'>
